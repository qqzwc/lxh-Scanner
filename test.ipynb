# %%
from PIL import Image
from PIL import ImageEnhance
import matplotlib.pyplot as plt

image = Image.open("./test_imgs/test4.jpg")

enhancer = ImageEnhance.Sharpness(image)
new_image = enhancer.enhance(3)

plt.imshow(new_image)

# %%
import matplotlib.pyplot as plt
import cv2
from scanner1 import get_rectangle
from py_utils import four_point_transform

mask = cv2.imread("testMask.png")
img_height = 300
img_path = "./test_imgs/test1.jpg"
# img_path = "C:/Users/leexi/Desktop/hhh.png"
img = cv2.imread(img_path)
cv2.resize(img, None, 0.5, 0.5)
assert img is not None, "Can't open {img_path}"

autoRect = get_rectangle(mask, img_height)

warpedImg = four_point_transform(img, autoRect)
plt.imshow(warpedImg)

# %%
plt.imshow(mask)

# %%
plt.imshow(img)
